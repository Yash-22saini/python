# %%
import pandas as pd

# %%
df=pd.read_csv("best place visit in india.csv")
df
# Out:
#               Best places to visit   Rating                        Location  \
# 0                        1. Gulmarg     4.4  Located in : Jammu and Kashmir
# 1                         2. Munnar     4.2             Located in : Kerala
# 2                        3. Gangtok     4.6             Located in : Sikkim
# 3                         4. Manali     4.8   Located in : Himachal Pradesh
# 4                       5. Srinagar     4.2  Located in : Jammu and Kashmir
# 5                       6. Shillong     4.2          Located in : Meghalaya
# 6                           7. Ooty     4.5         Located in : Tamil Nadu
# 7                     8. Darjeeling     4.8        Located in : West Bengal
# 8                         9. Ladakh     4.7                             NaN
# 9                     10. Rishikesh     4.5        Located in : Uttarakhand
# 10                        11. Coorg     4.2          Located in : Karnataka
# ...

# %%
df2=pd.DataFrame(df)
max_rating=df["Rating"].idxmax()
df2=df.iloc[max_rating]
df2
# Out:
# Best places to visit                                                 21. Agra
# Rating                                                                    4.9
# Location                                           Located in : Uttar Pradesh
#  Famous place to visit 1                                            Taj Mahal
# Famous place to visit 2                                             Agra Fort
# Famous place to visit                                          Fatehpur Sikri
# Description                 Located on the banks of River Yamuna in Uttar ...
# Best time to visit                                           October to March
# For package details         https://www.holidify.com/places/agra/packages....
# Name: 20, dtype: object
