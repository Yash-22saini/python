# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("covid_toy.csv")

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df.isnull().sum() ### for check the missing values .
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever'] = df['fever'].fillna(100)

# %%
df['fever'].mean()
# Out:
# np.float64(100.76)

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
# Loc And Iloc 

# df.loc[row_range , column_name]  ---> Last index value will be include . 
# df.iloc[row_range , column_range] ---> Last index value will not be include .

# %%
df.loc[2:5 , ['age' , 'gender' , 'has_covid']]
# Out:
#    age  gender has_covid
# 2   42    Male        No
# 3   31  Female        No
# 4   65  Female        No
# 5   84  Female       Yes

# %%
df.iloc[2:5 , [0,1,2]]
# Out:
#    age  gender  fever
# 2   42    Male  101.0
# 3   31  Female   98.0
# 4   65  Female  101.0

# %%
df2 = df.copy()

# %%
df2.loc[2:5 , ['age' , 'fever']] = 900
df2
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2   900    Male  900.0    Mild      Delhi        No
# 3   900  Female  900.0    Mild    Kolkata        No
# 4   900  Female  900.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df2['Gender'] = df2['gender'].map({"Male":0 , "Female":1}) ## map() will apply on gender column and
# change male to 0 and female to 1 . 
df2
# Out:
#     age  gender  fever   cough       city has_covid  Gender
# 0    60    Male  103.0    Mild    Kolkata        No       0
# 1    27    Male  100.0    Mild      Delhi       Yes       0
# 2   900    Male  900.0    Mild      Delhi        No       0
# 3   900  Female  900.0    Mild    Kolkata        No       1
# 4   900  Female  900.0    Mild     Mumbai        No       1
# ..  ...     ...    ...     ...        ...       ...     ...
# 95   12  Female  104.0    Mild  Bangalore        No       1
# 96   51  Female  101.0  Strong    Kolkata       Yes       1
# 97   20  Female  101.0    Mild  Bangalore        No       1
# 98    5  Female   98.0  Strong     Mumbai        No       1
# 99   10  Female   98.0  Strong    Kolkata       Yes       1
#
# [100 rows x 7 columns]

# %%
df2 = df2.drop(columns = ['Gender'])

# %%
df.sort_index() # for sequenece wise sorting
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df = df.rename(columns = {
    "gender" : "Updated_gender" , 
    "fever" :  "Latest_updated_fever"
})

# %%
df
# Out:
#     age Updated_gender  Latest_updated_fever   cough       city has_covid
# 0    60           Male                 103.0    Mild    Kolkata        No
# 1    27           Male                 100.0    Mild      Delhi       Yes
# 2    42           Male                 101.0    Mild      Delhi        No
# 3    31         Female                  98.0    Mild    Kolkata        No
# 4    65         Female                 101.0    Mild     Mumbai        No
# ..  ...            ...                   ...     ...        ...       ...
# 95   12         Female                 104.0    Mild  Bangalore        No
# 96   51         Female                 101.0  Strong    Kolkata       Yes
# 97   20         Female                 101.0    Mild  Bangalore        No
# 98    5         Female                  98.0  Strong     Mumbai        No
# 99   10         Female                  98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df = df[['age' , 'Latest_updated_fever' , 'has_covid']]

# %%
df
# Out:
#     age  Latest_updated_fever has_covid
# 0    60                 103.0        No
# 1    27                 100.0       Yes
# 2    42                 101.0        No
# 3    31                  98.0        No
# 4    65                 101.0        No
# ..  ...                   ...       ...
# 95   12                 104.0        No
# 96   51                 101.0       Yes
# 97   20                 101.0        No
# 98    5                  98.0        No
# 99   10                  98.0       Yes
#
# [100 rows x 3 columns]

# %%
df2.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2  900   Male  900.0  Mild    Delhi        No

# %%
df2.loc[2:5 , ['age' , 'gender' , 'has_covid']] = None

# %%
df2.isnull().sum()
# Out:
# age          4
# gender       4
# fever        0
# cough        0
# city         0
# has_covid    4
# dtype: int64

# %%
df.shape
# Out:
# (100, 3)

# %%
df2 = df2.dropna()

# %%
df2.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df2.shape
# Out:
# (96, 6)
