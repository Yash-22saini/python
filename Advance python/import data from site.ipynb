# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("flipkart.csv")
df
# Out:
#                                              Name  Star         Ratings  \
# 0      CMF by Nothing Phone 2 Pro (Black, 128 GB)   4.4   7,437 Ratings
# 1               Nothing Phone (3a) (Blue, 256 GB)   4.5  22,183 Ratings
# 2               realme GT 6 (Razor Green, 256 GB)   4.5   1,905 Ratings
# 3             vivo T3 Ultra (Frost Green, 256 GB)   4.5   8,608 Ratings
# 4              realme GT 6 (Fluid Silver, 256 GB)   4.5   3,139 Ratings
# 5          realme 14 Pro+ 5G (Suede Grey, 512 GB)   4.4   5,014 Ratings
# 6          realme 14 Pro+ 5G (Suede Grey, 256 GB)   4.4   5,014 Ratings
# 7              realme GT 6 (Fluid Silver, 512 GB)   4.5   4,986 Ratings
# 8               realme GT 6 (Razor Green, 256 GB)   4.5   3,139 Ratings
# 9         realme 14 Pro+ 5G (Pearl White, 512 GB)   4.4   5,014 Ratings
# 10             vivo T3 Ultra (Lunar Gray, 256 GB)   4.5   8,608 Ratings
# 11           vivo V50e 5G (Sapphire Blue, 256 GB)   4.4     804 Ratings
# ...

# %%
df.shape   ### total rows and columns
# Out:
# (24, 11)

# %%
df.columns   ### returns all column names of the data frame
# Out:
# Index(['Name', 'Star', 'Ratings', 'Reiews', 'Memory', 'Display', 'Camera',
#        'Battery', 'Processor', 'Warranty', 'Price'],
#       dtype='object')

# %%
### top  5 data 
df.head()
# Out:
#                                          Name  Star         Ratings  \
# 0  CMF by Nothing Phone 2 Pro (Black, 128 GB)   4.4   7,437 Ratings
# 1           Nothing Phone (3a) (Blue, 256 GB)   4.5  22,183 Ratings
# 2           realme GT 6 (Razor Green, 256 GB)   4.5   1,905 Ratings
# 3         vivo T3 Ultra (Frost Green, 256 GB)   4.5   8,608 Ratings
# 4          realme GT 6 (Fluid Silver, 256 GB)   4.5   3,139 Ratings
#
#           Reiews                                        Memory  \
# 0    760 Reviews  8 GB RAM | 128 GB ROM | Expandable Upto 2 TB
# 1  2,068 Reviews                         8 GB RAM | 256 GB ROM
# 2    190 Reviews                        12 GB RAM | 256 GB ROM
# 3    689 Reviews                        12 GB RAM | 256 GB ROM
# 4    347 Reviews                         8 GB RAM | 256 GB ROM
#
#                                  Display  \
# 0            17.2 cm (6.77 inch) Display
# 1   43.66 cm (17.19 cm) Full HD+ Display
# 2  17.22 cm (6.78 inch) Full HD+ Display
# ...

# %%
### bottom 5 data
df.tail()
# Out:
#                                              Name  Star         Ratings  \
# 19        realme 14 Pro+ 5G (Pearl White, 256 GB)   4.4   5,014 Ratings
# 20  Samsung Galaxy A36 5G (Awesome White, 256 GB)   4.3     595 Ratings
# 21                 vivo V50 5G (Rose Red, 128 GB)   4.5   4,914 Ratings
# 22           OnePlus 13R 5G (Nebula Noir, 256 GB)   4.5   1,672 Ratings
# 23                  Google Pixel 7 (Snow, 128 GB)   4.3  18,872 Ratings
#
#            Reiews                  Memory  \
# 19    634 Reviews  12 GB RAM | 256 GB ROM
# 20     51 Reviews   8 GB RAM | 256 GB ROM
# 21    457 Reviews   8 GB RAM | 128 GB ROM
# 22    135 Reviews  12 GB RAM | 256 GB ROM
# 23  2,088 Reviews   8 GB RAM | 128 GB ROM
#
#                                  Display  \
# 19          17.35 cm (6.83 inch) Display
# 20  17.02 cm (6.7 inch) Full HD+ Display
# 21           17.2 cm (6.77 inch) Display
# 22          17.22 cm (6.78 inch) Display
# 23   16.0 cm (6.3 inch) Full HD+ Display
#
# ...

# %%
### statically view of data
df.describe()
# Out:
#             Star
# count  24.000000
# mean    4.454167
# std     0.065801
# min     4.300000
# 25%     4.400000
# 50%     4.500000
# 75%     4.500000
# max     4.500000

# %%
## all information about the data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       24 non-null     object
#  1   Star       24 non-null     float64
#  2   Ratings    24 non-null     object
#  3   Reiews     24 non-null     object
#  4   Memory     24 non-null     object
#  5   Display    24 non-null     object
#  6   Camera     24 non-null     object
#  7   Battery    24 non-null     object
#  8   Processor  24 non-null     object
#  9   Warranty   20 non-null     object
#  10  Price      24 non-null     object
# dtypes: float64(1), object(10)
# memory usage: 2.2+ KB

# %%
### best place to visit in jaipur data

# %%
df = pd.read_csv("best palce jaipur.csv")
df
# Out:
#                                             Names                Must_visit  \
# 0                                     1. Amer Fort           Top Attraction
# 1                                    2. Hawa Mahal           Top Attraction
# 2                           3. City Palace, Jaipur         Instagram Worthy
# 3                          4. Jantar Mantar Jaipur           Top Attraction
# 4                                5. Nahargarh Fort  Great For Family Outing
# 5                                  6. Jaigarh Fort                      NaN
# 6                                     7. Jal Mahal                      NaN
# 7                            8. Albert Hall Museum                      NaN
# 8                                  9. Birla Temple           Top Attraction
# 9                          10. Chokhi Dhani Jaipur                      NaN
# 10                                11. Masala Chowk     Popular among Locals
# ...

# %%
df.head()
# Out:
#                     Names                Must_visit               Distance   \
# 0             1. Amer Fort           Top Attraction  10 km from city center
# 1            2. Hawa Mahal           Top Attraction   4 km from city center
# 2   3. City Palace, Jaipur         Instagram Worthy   4 km from city center
# 3  4. Jantar Mantar Jaipur           Top Attraction   4 km from city center
# 4        5. Nahargarh Fort  Great For Family Outing   4 km from city center
#
#               Type  Rating
# 0  Forts & Palaces     4.6
# 1  Forts & Palaces     4.5
# 2  Forts & Palaces     4.5
# 3         Monument     4.5
# 4  Forts & Palaces     4.3

# %%
df.tail()
# Out:
#                                  Names  Must_visit               Distance   \
# 47  48. Angel Resort and Amusement Park        NaN  18 km from city center
# 48                        49. Bhandarej        NaN  63 km from city center
# 49                    50. Samode Palace        NaN  33 km from city center
# 50                51. Hari Mahal Palace        NaN   0 km from city center
# 51                  52. Rajmahal Palace        NaN   1 km from city center
#
#                       Type  Rating
# 47  Amusement & Theme Park     NaN
# 48                 Village     NaN
# 49         Forts & Palaces     NaN
# 50         Forts & Palaces     NaN
# 51         Forts & Palaces     NaN

# %%
df.describe()
# Out:
#           Rating
# count  33.000000
# mean    4.439394
# std     0.224916
# min     3.700000
# 25%     4.300000
# 50%     4.500000
# 75%     4.600000
# max     4.800000

# %%
df.columns
# Out:
# Index(['Names ', 'Must_visit', 'Distance ', 'Type', 'Rating'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Names       52 non-null     object
#  1   Must_visit  22 non-null     object
#  2   Distance    51 non-null     object
#  3   Type        50 non-null     object
#  4   Rating      33 non-null     float64
# dtypes: float64(1), object(4)
# memory usage: 2.2+ KB
